# %% [markdown]
# ![Screenshot 2024-02-11 at 1.15.03 PM.png](attachment:ada06c10-4cbc-42a1-9f8a-15dfc42b1b50.png)
#
# ## COMSC174 LAB 6
#
# Use the reference below for writing logic expressions (and making Truth Tables) in Sagemath:
# * [Symbolic Logic Expressions in Sagemath (reference)](https://doc.sagemath.org/html/en/reference/logic/sage/logic/logic.html)

# %% [markdown]
# &nbsp;
#
# ### Question 1:
#
# Negate the following statement, then produce a truth table based on the results.  What law would you use?
#
# (∼p ∨ q) ∧ ∼(p ∧ q)

# %%
# question 1 response goes in here 
# be sure to edit or remove these comments
# and replace them with your own
# for example, you can answer "What law would you use" in a comment
# before, or in the middle of, your Sagemath code.

# %% [markdown]
# &nbsp;
#
# ### Question 2:
#
# Create a truth table and determine whether or not the following statement is a tautology, a contradiction, or neither.
#
# ∼(∼p∧q)∧(p∨q)

# %%
# question 2 response goes in here 
# be sure to edit or remove these comments
# and replace them with your own
# for example, you can answer 
# "determine whether or not the following statement is a tautology, a contradiction,
# or neither" in a comment, along with your sagemath code.

# %% [markdown]
# &nbsp;
#
# ### Question 3:
#
# Create a truth table and determine whether or not the following statement is a tautology, a contradiction, or neither.
#
# (p∧∼q)∧(∼p∨q)

# %%
# Question 3 response goes in here

# %% [markdown]
# &nbsp;
#
# ### Question 4:
#
# Complete a truth table and determine whether or not the following statement is a tautology, a contradiction, or neither.
#
# (p ∧ (p → q)) → q

# %%
# Question 4 response goes in here

# %% [markdown]
# &nbsp;
#
# ### Question 5:
#
# Complete the truth table and determine whether or not the following statement is a tautology, a contradiction, or neither.
#
# ((∼ p ∧ q) ∧ (q ∧ r))∧ ∼ q

# %%
# Question 5 response goes in here

# %% [markdown]
# &nbsp;
# <img style="float: right;" src="attachment:430cf82a-7f00-4e35-8b98-3ca1f7f05cfe.jpg">
#
# ### Question 6:
#
# Hatsune Miku is not real.  Her music is real.  Write this as a logical expression.  Then create a truth table based on the two proposition.  Can you negate the first proposition without negating the second?  How?

# %%
# Question 6 response goes in here.  
# Also, my daughter made this question.
