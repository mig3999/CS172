# %% [markdown]
# ![Screenshot 2024-03-03 at 8.39.58 pm.png](attachment:03b1f3ad-648d-4082-9871-ac5ca9ec4941.png)
#
# ## COMSC 172 Lab 7
#
# Check out the reference on [Propositional Calculus](https://doc.sagemath.org/html/en/reference/logic/sage/logic/propcalc.html)
#
# Here's an example from the reference.  Press run inside the following cell to see the result.

# %%
f = propcalc.formula("a&((b|c)^a->c)<->b")
g = propcalc.formula("boolean<->algebra")
(f&~g).ifthen(f)
# Out:
# ((a&((b|c)^a->c)<->b)&(~(boolean<->algebra)))->(a&((b|c)^a->c)<->b)

# %% [markdown]
# And you can always create any truth table using the variable.truthtable method, like this:

# %%
f = propcalc.formula("a&((b|c)^a->c)<->b")
f.truthtable()
# Out:
# a      b      c      value
# False  False  False  True
# False  False  True   True
# False  True   False  False
# False  True   True   False
# True   False  False  True
# True   False  True   False
# True   True   False  True
# True   True   True   True

# %% [markdown]
# Other stuff you can do in SageMath, [(according to the reference)](https://doc.sagemath.org/html/en/reference/logic/sage/logic/propcalc.html), includes:
#
# * contradictions
# * tautologies
# * compare for semantic equivalence using ==
#
# &nbsp;

# %% [markdown]
# Note that in the following questions, you can add more cells by pressing the little ![Screenshot 2024-02-29 at 11.05.14 am.png](attachment:f662ded1-0c30-47b6-9f24-1699aea251ae.png) button.

# %% [markdown]
# ## Excercise 1:
#
# Create truth tables for the following logical expressions:
#
# * (a) p∧q
# * (b) p∨q
# * (c) p→q
# * (d) (p∧q)∨(¬p∧q)

# %%
# Question 1 response in here
# (create more cells if needed)

# %% [markdown]
# &nbsp;
#
# ## Excercise 2:
#
# Determine whether the following expressions are contradictions, tautologies, or neither:
#
# * (a) p∧¬p
# * (b) (p∨q)→p
# * (c) p∨¬p
# * (d) (p∧q)∨(¬p∧q)

# %%
# Excercise 2 response in here

# %% [markdown]
# &nbsp;
#
# ## Excercise 3:
#
# Determine whether the following pairs of expressions are semantically equivalent:
#
# * (a) p∧(q∨r) and (p∧q)∨(p∧r)
# * (b) p→(q∧r) and (p→q)∧(p→r)
# * (c) ¬(p∧q) and ¬p∨¬q

# %%
# Excercise 3 response in here

# %% [markdown]
# &nbsp;
#
# ## Excercise 4:
# Consider the following real-world scenarios and represent them using propositional logic. Then, analyze the implications using SageMath:
#
# * **Scenario 1**: If it's raining, then I'll take my umbrella. I'm taking my umbrella. Is it raining?
# * **Scenario 2**: A necessary condition for a student to pass the course is to pass the final exam. John passed the final exam. Did John pass the course?
# * **Scenario 3**: A lamp will turn on if and only if both the switch is flipped and there is electricity. The lamp is turned on. Is the switch flipped? Is there electricity?
#
# use SageMath to construct truth tables, evaluate logical expressions, and check for semantic equivalence between expressions

# %%
# Excercise 4 goes here.  Add more cells if needed.
