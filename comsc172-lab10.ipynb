# %% [markdown]
# ![Screenshot 2024-03-24 at 8.18.21 PM.png](attachment:706dc5de-1ec6-477d-9c49-96e1a9309300.png)
# ## Lab 10

# %% [markdown]
# <img style="float: right;" src="attachment:3e29d62e-6043-4852-b06b-18a8eb24b0f0.gif" width="200px">
#
# There are a bunch of ways to graph or display *Relations* in Sagemath.  Here are a few examples, which are from the Sagemath reference pages:
# * [Finite Posets](https://doc.sagemath.org/html/en/reference/combinat/sage/combinat/posets/posets.html)
# * [Digraphs in Sagemaths](https://doc.sagemath.org/html/en/reference/graphs/sage/graphs/digraph.html)
# * [Hasse Diagrams of posets](https://doc.sagemath.org/html/en/reference/combinat/sage/combinat/posets/hasse_diagram.html)
# * [Graph Plotting](https://doc.sagemath.org/html/en/reference/plotting/sage/graphs/graph_plot.html)

# %%
# You can draw a graph using the Graph object like this:
# (press run to see it in action)
G = Graph()
G.add_edge(1,2)
G.add_edge(2,3)
G.add_edge(3,1)
G

# %%
# you can also create a diagram using the DiGraph class like this:
# and there are other methods and classes described in the references above
G = DiGraph({0: [1, 2, 3], 2: [4]})
G.show()

# %% [markdown]
# &nbsp;
#
# ### Question #1
#
# $\text{Let }A = \{0, 1,2,3\}\text{, and let }\begin{equation*}
# r = \{(0, 0), (0, 3), (1, 2), (2, 1), (3, 2), (2, 0)\}
# \end{equation*}$
#
# Draw a digraph of r.

# %%
# question 1 response

# %% [markdown]
# &nbsp;
#
# ### Question #2
#
# Let $A = \{1, 2, 3, 4\}$ and let *r* be the relation $\leq$ on *A*.
#
# Draw a digraph for *r*.

# %%
#question 2 response in here

# %% [markdown]
# &nbsp;
#
# ### Question #3
#
# Let $B = \{1,2, 3, 4, 6, 8, 12, 24\}$, and let *s* be the relation "divides" on *B*.
#
# Draw a digraph for *s*.

# %%
#question 3

# %% [markdown]
# &nbsp;
#
# ### Question #4
#
# Let $A=\{1,2,3,4,5\}$.  Define $t$ on $A$ by $a t b$ if and ony if $b - a$ is even.
#
# Draw a digraph for $t$.

# %%
#question 4

# %% [markdown]
# &nbsp;
#
# ### Question #5
#
# Let $A$ be the set of strings of 0’s and 1’s of length 3 or less. This includes the empty string, $\lambda$, which is the only string of length zero.
#
# * a. Define the relation of $d$ on $A$ by $xdy$ if $x$ is contained within $y$. For example, $01 d 101$. Draw a digraph for this relation.
# * b. Do the same for the relation $p$ defined by $xpy$ if $x$ is a prefix of $y$. For example, $10p101$, but $01p101$ is false.

# %%
# Question 5 in here.  Add more cells if needed.

# %% [markdown]
# &nbsp;
#
# ### Question #6
#
# Let $C= \{1,2, 3, 4, 6, 8, 12, 24\}$ and define $t$ on $C$ by $atb$ if and only if $a$ and $b$ share a common divisor greater than 1.
#
# Draw a digraph for $t$.

# %%
# Question 6
